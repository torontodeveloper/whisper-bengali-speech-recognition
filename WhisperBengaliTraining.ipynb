# %% [markdown]
# <a href="https://colab.research.google.com/github/torontodeveloper/whisper-bengali-speech-recognition/blob/main/WhisperBengaliTraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets==2.13.1

# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle

# %%
# !chmod 777 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download ben10
# Out:
# ...
# 100% 6.80G/6.80G [01:30<00:00, 55.3MB/s]
# 100% 6.80G/6.80G [01:30<00:00, 80.4MB/s]

# %%
# !unzip ben10.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ben10/16kHz_train_audio/train_sylhet (1686).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1687).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1688).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1689).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (169).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1690).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1691).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1692).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1693).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1694).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1695).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1696).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1697).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1698).wav
#   inflating: ben10/16kHz_train_audio/train_sylhet (1699).wav
# ...

# %%
import pandas as pd
from datasets import Dataset

# %%
train_df = pd.read_csv('/content/ben10/train.csv')

# %%
BASE_DIR = '/content/ben10/'
train_data_dir =f'{BASE_DIR}/16kHz_train_audio'
test_data_dir = f'{BASE_DIR}/16kHz_valid_audio'
data_path=f'{BASE_DIR}/train.csv'
